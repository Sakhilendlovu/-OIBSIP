# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as  sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("car data.csv")
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# ...

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
data.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
data = data.dropna()

# %%
data = data.drop_duplicates()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv("car data.csv")
#Show Histogram
plt.style.use("dark_background")
sns.set_palette('dark')

data = data.rename(columns={"price": "Price"})

#sns.histplot(data["Price"])
plt.title('Distribution of Car Price', color = 'green')
plt.xlabel('Price', color = 'green')
plt.ylabel('Count', color = 'green')
plt.show()

#Show Heatmap
numeric_features = ['wheelbase', 'car_length', 'car_width', 'car_height', 'car_weight', 'engine_size', 'bore_ratio', 'stake', 'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg', 'highway_mpg', 'price']
#correlation_matrix = data[numeric_features].corr()
#plt.figure(figuresize=(10, 8))
#sns.heatmap(correlation_matrix, annot = True, cmap = 'Coolwarm')
plt.title('correlation Heatmap', color = 'green')
plt.xticks(color = 'green')
plt.yticks(color = 'green')
plt.show()
#print(data.columns)
